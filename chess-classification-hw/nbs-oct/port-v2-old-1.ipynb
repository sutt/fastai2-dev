# %%
# !pip list
# Out:
# Package               Version             Location
# --------------------- ------------------- ---------------------------------------------------------
# albumentations        0.4.5
# asn1crypto            1.3.0
# attrs                 19.3.0
# backcall              0.1.0
# beautifulsoup4        4.9.0
# bleach                3.1.0
# blis                  0.2.4
# Bottleneck            1.3.2
# certifi               2019.11.28
# cffi                  1.13.2
# chardet               3.0.4
# click                 7.1.1
# cryptography          2.8
# cycler                0.10.0
# cymem                 2.0.2
# decorator             4.4.1
# defusedxml            0.6.0
# entrypoints           0.3
# fastai                1.0.61
# fastcore              0.1.11              /mnt/c/Users/wsutt/Desktop/files/fastai2-dev/fastcore-win
# fastprogress          0.2.2
# fastscript            0.1.4
# Flask                 1.1.1
# idna                  2.8
# imagecodecs           2020.2.18
# imageio               2.6.1
# imgaug                0.2.6
# importlib-metadata    1.5.0
# imutils               0.5.3
# inflect               4.1.0
# ipykernel             5.1.4
# ipython               7.12.0
# ipython-genutils      0.2.0
# ipywidgets            7.5.1
# itsdangerous          1.1.0
# jaraco.itertools      5.0.0
# jedi                  0.16.0
# Jinja2                2.11.1
# joblib                0.14.1
# jsonpickle            1.3
# jsonschema            3.2.0
# jupyter               1.0.0
# jupyter-client        5.3.4
# jupyter-console       6.1.0
# jupyter-core          4.6.1
# kaggle                1.5.6
# kiwisolver            1.1.0
# kornia                0.2.0
# MarkupSafe            1.1.1
# matplotlib            3.1.3
# mistune               0.8.4
# mkl-fft               1.0.15
# mkl-random            1.1.0
# mkl-service           2.3.0
# more-itertools        8.2.0
# munch                 2.5.0
# murmurhash            1.0.2
# nbconvert             5.6.1
# nbdev                 0.2.9
# nbformat              5.0.4
# networkx              2.4
# notebook              6.0.3
# numexpr               2.7.1
# numpy                 1.18.1
# nvidia-ml-py3         7.352.0
# olefile               0.46
# opencv-contrib-python 4.2.0.32
# opencv-python         4.2.0.32
# openslide-python      1.1.1
# packaging             20.1
# pandas                1.0.0
# pandocfilters         1.4.2
# parso                 0.6.0
# pexpect               4.8.0
# pickleshare           0.7.5
# Pillow                6.2.1
# pip                   20.0.2
# plac                  0.9.6
# preshed               2.0.1
# pretrainedmodels      0.7.4
# prometheus-client     0.7.1
# prompt-toolkit        3.0.3
# ptyprocess            0.6.0
# pyarrow               0.15.1
# pycparser             2.19
# pydicom               1.4.1
# Pygments              2.5.2
# pyOpenSSL             19.1.0
# pyparsing             2.4.6
# pyrsistent            0.15.7
# PySocks               1.7.1
# python-dateutil       2.8.1
# python-slugify        4.0.0
# pytz                  2019.3
# PyWavelets            1.1.1
# PyYAML                5.3
# pyzmq                 18.1.1
# qtconsole             4.6.0
# requests              2.22.0
# scikit-image          0.16.2
# scikit-learn          0.22.1
# scipy                 1.4.1
# Send2Trash            1.5.0
# setuptools            45.1.0.post20200127
# Shapely               1.7.0
# six                   1.14.0
# soupsieve             2.0
# spacy                 2.1.8
# srsly                 0.1.0
# terminado             0.8.3
# testpath              0.4.4
# text-unidecode        1.3
# thinc                 7.0.8
# tifffile              2020.2.16
# torch                 1.4.0
# torchvision           0.5.0
# tornado               6.0.3
# tqdm                  4.42.0
# traitlets             4.3.3
# urllib3               1.24.3
# wasabi                0.2.2
# wcwidth               0.1.8
# webencodings          0.5.1
# Werkzeug              1.0.0
# wheel                 0.34.2
# widgetsnbextension    3.5.1
# zipp                  2.1.0

# %%
# import fastai2

# %%
# from utils import *
from fastai2.vision.all import *
# from nbdev.showdoc import *
from ipywidgets import widgets
from pandas.api.types import CategoricalDtype

import matplotlib as mpl
# mpl.rcParams['figure.dpi']= 200
mpl.rcParams['savefig.dpi']= 200
mpl.rcParams['font.size']=12

set_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
pd.set_option('display.max_columns',999)
np.set_printoptions(linewidth=200)
torch.set_printoptions(linewidth=200)

from fastai2.vision.widgets import *
import time

# %%
def piece_class_parse(fn): 
    fn = fn.split('_')[1]
    fn = fn.split('.')[0]
    return fn

# %%
learn = load_learner('../models/base-learner-13-fit25.pkl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-fb7945cbe5dd> in <module>
# ----> 1 learn = load_learner('../models/base-learner-13-fit25.pkl')
#
# /mnt/c/Users/wsutt/Desktop/files/fastai2-dev/sutt-fastai2-wsl/fastai2/learner.py in load_learner(fname, cpu)
#     524     "Load a `Learner` object in `fname`, optionally putting it on the `cpu`"
#     525     distrib_barrier()
# --> 526     res = torch.load(fname, map_location='cpu' if cpu else None)
#     527     if hasattr(res, 'to_fp32'): res = res.to_fp32()
#     528     if cpu: res.dls.cpu()
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     527             with _open_zipfile_reader(f) as opened_zipfile:
#     528                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
# --> 529         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     530
#     531
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/serialization.py in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#     700     unpickler = pickle_module.Unpickler(f, **pickle_load_args)
#     701     unpickler.persistent_load = persistent_load
# --> 702     result = unpickler.load()
#     703
#     704     deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#
# ModuleNotFoundError: No module named 'modules'
