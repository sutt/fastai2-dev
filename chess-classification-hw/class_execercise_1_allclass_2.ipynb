# %%
# from utils import *
from fastai2.vision.all import *
from nbdev.showdoc import *
from ipywidgets import widgets
from pandas.api.types import CategoricalDtype

import matplotlib as mpl
# mpl.rcParams['figure.dpi']= 200
mpl.rcParams['savefig.dpi']= 200
mpl.rcParams['font.size']=12

set_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
pd.set_option('display.max_columns',999)
np.set_printoptions(linewidth=200)
torch.set_printoptions(linewidth=200)

from fastai2.vision.widgets import *

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
path = Path('../../other-chess-data/bing-search/')
fns = get_image_files(path)  # works recursively, to each subfolder

failed = verify_images(fns)

# %%
failed.map(Path.unlink)
# Out:
# (#0) []

# %%
pieces = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.3, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = pieces.dataloaders(path)

# %%
list(dls.vocab)
# Out:
# ['bishop-chess-piece',
#  'king-chess-piece',
#  'knight-chess-piece',
#  'pawn-chess-piece',
#  'queen-chess-piece',
#  'rook-chess-piece']

# %%
dls.valid.show_batch(max_n=12, nrows=4)

# %%
pieces = pieces.new(
    item_tfms=RandomResizedCrop(128, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = pieces.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.010796</td>
#       <td>1.256356</td>
#       <td>0.434211</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.854352</td>
#       <td>1.007518</td>
#       <td>0.342105</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.656639</td>
#       <td>0.826150</td>
#       <td>0.267544</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.424249</td>
#       <td>0.797062</td>
#       <td>0.258772</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.231627</td>
#       <td>0.758703</td>
#       <td>0.250000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.091929</td>
#       <td>0.707106</td>
#       <td>0.241228</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.982274</td>
#       <td>0.693430</td>
#       <td>0.236842</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export('models/bing-clean-1.pkl')

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.706814</td>
#       <td>1.705505</td>
#       <td>0.548246</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.931686</td>
#       <td>1.261859</td>
#       <td>0.434211</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.770113</td>
#       <td>0.993985</td>
#       <td>0.350877</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.562211</td>
#       <td>0.858123</td>
#       <td>0.289474</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.349675</td>
#       <td>0.794568</td>
#       <td>0.263158</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.157220</td>
#       <td>0.731465</td>
#       <td>0.232456</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.039968</td>
#       <td>0.654402</td>
#       <td>0.214912</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.934629</td>
#       <td>0.656014</td>
#       <td>0.206140</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.830532</td>
#       <td>0.643806</td>
#       <td>0.197368</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.759364</td>
#       <td>0.650768</td>
#       <td>0.192982</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.704999</td>
#       <td>0.641724</td>
#       <td>0.201754</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export('models/bing-clean-2.pkl')

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=5)

# %%
interp.plot_top_losses(5, nrows=5)

# %%
import os
from IPython.display import display
def plt_img(fn):
    pic = Image.open(fn)
    pic = pic.resize((100,100))
    display(pic)

# %%
all_deletes = []

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# VBox(children=(Dropdown(options=('bishop-chess-piece', 'king-chess-piece', 'knight-chess-piece', 'pawn-chess-p…

# %%
deletes = [cleaner.fns[e] for e in cleaner.delete()]
all_deletes.extend(deletes)

# %%
all_deletes
# Out:
# [Path('../../other-chess-data/bing-search/knight-chess-piece/00000131.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000114.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000133.jpeg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000116.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000083.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000123.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000120.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000044.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000117.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000104.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000145.jpg'),
#  Path('../../other-chess-data/bing-search/knight-chess-piece/00000098.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000111.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000092.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000124.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000148.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000049.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000087.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000101.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000071.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000041.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000125.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000023.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000075.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000085.jpg'),
#  Path('../../other-chess-data/bing-search/bishop-chess-piece/00000022.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000089.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000113.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000046.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000121.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000141.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000077.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000070.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000120.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000034.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000028.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000058.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000032.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000036.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000124.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000084.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000072.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000140.jpg'),
#  Path('../../other-chess-data/bing-search/king-chess-piece/00000053.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000096.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000039.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000139.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000102.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000090.png'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000068.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000118.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000053.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000047.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000105.jpeg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000074.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000122.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000029.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000043.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000113.jpg'),
#  Path('../../other-chess-data/bing-search/pawn-chess-piece/00000052.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000118.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000041.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000145.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000123.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000043.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000080.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000040.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000012.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000119.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000061.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000072.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000079.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000077.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000004.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000065.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000146.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000125.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000120.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000088.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000148.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000071.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000103.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000106.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000137.jpg'),
#  Path('../../other-chess-data/bing-search/queen-chess-piece/00000015.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000051.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000138.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000147.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000053.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000098.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000103.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000148.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000032.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000095.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000097.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000130.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000125.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000123.jpg'),
#  Path('../../other-chess-data/bing-search/rook-chess-piece/00000134.jpg')]

# %%
#before
# !ls -R ../../other-chess-data/bing-search/ | wc -l
# Out:
# 883

# %%
for d in all_deletes:
    try:
        os.remove(d)
    except:
        pass

# %%
#after
# !ls -R ../../other-chess-data/bing-search/ | wc -l
# Out:
# 784

# %%
#before
# !ls ../../other-chess-data/bing-search/bishop-chess-piece/ | wc -l
# Out:
# 147

# %%
[plt_img(e) for e in list(deletes)]
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6D20C350>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6CA522D0>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6CEE7410>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6CEE7410>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6CA522D0>
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x7FFA6DCDEA50>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6D20C350>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6CFD3F50>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6D0D2D10>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6D0D2D10>
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FFA6D20C350>
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
# !ls ~/other-chess-data/bing-search/bishop-chess-piece | wc -l
# Out:
# 147

# %%
cleaner.change()
# Out:
# (#0) []

# %%
?? cleaner

# %%
learn.export('models/chess1.pkl')

# %%
# !ls models
# Out:
# chess1.pkl
