# %% [markdown]
# ### Load a model

# %%
from fastai2.vision.all import *
from fastai2.basics import *
from torchvision.models import vgg19, vgg16
from PIL import Image
from imports.suttstyle import StyleImport

# %%
url = 'https://images.fineartamerica.com/images/artworkimages/medium/1/watercolor-colorado-winter-wonderland-cascade-colors.jpg'
model_fn = 'watercolor_model'

# %%
s = StyleImport()

# %%
img_fn = s.pull_style_target(url)

style_img = Image.open(img_fn)
style_img.resize((250,250))
# Out:
# saving to file: style3.jpg
# success!
# b''
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7F26A91E1E10>

# %%
_ = s.build_feats()
loss_func = s.build_loss_func(style_fn = img_fn)
tnet = s.build_arch()
dls = s.build_dls()

# %%
learn = Learner(dls, tnet, loss_func=loss_func)

# %%
learn.fit_one_cycle(1,1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>16.290207</td>
#       <td>16.519642</td>
#       <td>21:25</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(model_fn)

# %%
pred_img2 = learn.predict('cat.jpg')
pred_img2[0].show()

# %%
pred_img = learn.predict('biggie_photo.jpg')
pred_img[0].show()

# %%
pred_img = learn.predict('mountain.jpg')
pred_img[0].show()

# %%
pred_img = learn.predict('jeremy.jpg')
pred_img[0].show()
